# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Cleaning

# %%
# Import data
df = pd.read_csv('investor_data.csv')
df.head()
# Out:
#     risk               clientID      dateID  avgMonthlyIncome education  \
# 0  0.592  user-0000000000000000  2021-11-01          272817.5       NaN
# 1  0.485  user-0000000000000001  2021-11-01          162850.8   college
# 2  0.300  user-0000000000000002  2021-11-01          640200.6   college
# 3  0.664  user-0000000000000003  2021-11-01           29308.5       BSc
# 4  0.643  user-0000000000000004  2021-11-01          420154.1       NaN
#
#    expSavings  expTransport  expGroceries  expLeisure  expShopping  \
# 0        0.20          0.09          0.12        0.16         0.14
# 1        0.16          0.15          0.11        0.14         0.14
# 2        0.18          0.08          0.09        0.13         0.23
# 3        0.12          0.13          0.07        0.18         0.26
# 4        0.09          0.14          0.21        0.12         0.11
#
#    expUtilities  expOther  cardLevel  amountDeposit  amountLoan  \
# 0          0.14      0.14          2            0.0         0.0
# 1          0.12      0.17          0            0.0    100000.0
# 2          0.10      0.19          1        50000.0         0.0
# 3          0.15      0.08          2            0.0         0.0
# 4          0.11      0.22          2            0.0         0.0
#
#    avgTransaction  avgNumTransactions  largestSingleTransaction
# 0          1454.8               185.5                   49832.0
# 1          3005.4               173.9                   49025.8
# 2         39649.6               556.2                   19337.5
# 3         22542.6               351.6                    4724.4
# 4          2744.4               310.5                    5445.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72000 entries, 0 to 71999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   risk                      72000 non-null  float64
#  1   clientID                  72000 non-null  object
#  2   dateID                    72000 non-null  object
#  3   avgMonthlyIncome          72000 non-null  float64
#  4   education                 50400 non-null  object
#  5   expSavings                72000 non-null  float64
#  6   expTransport              72000 non-null  float64
#  7   expGroceries              72000 non-null  float64
#  8   expLeisure                72000 non-null  float64
#  9   expShopping               72000 non-null  float64
#  10  expUtilities              72000 non-null  float64
#  11  expOther                  72000 non-null  float64
#  12  cardLevel                 72000 non-null  int64
#  13  amountDeposit             72000 non-null  float64
#  14  amountLoan                72000 non-null  float64
#  15  avgTransaction            72000 non-null  float64
#  16  avgNumTransactions        72000 non-null  float64
#  17  largestSingleTransaction  72000 non-null  float64
# dtypes: float64(14), int64(1), object(3)
# memory usage: 9.9+ MB

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# risk                            0
# clientID                        0
# dateID                          0
# avgMonthlyIncome                0
# education                   21600
# expSavings                      0
# expTransport                    0
# expGroceries                    0
# expLeisure                      0
# expShopping                     0
# expUtilities                    0
# expOther                        0
# cardLevel                       0
# amountDeposit                   0
# amountLoan                      0
# avgTransaction                  0
# avgNumTransactions              0
# largestSingleTransaction        0
# dtype: int64

# %%
# Drop missing values
df.dropna(inplace = True)
print(df.isnull().sum())
# Out:
# risk                        0
# clientID                    0
# dateID                      0
# avgMonthlyIncome            0
# education                   0
# expSavings                  0
# expTransport                0
# expGroceries                0
# expLeisure                  0
# expShopping                 0
# expUtilities                0
# expOther                    0
# cardLevel                   0
# amountDeposit               0
# amountLoan                  0
# avgTransaction              0
# avgNumTransactions          0
# largestSingleTransaction    0
# dtype: int64

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Drop column 'clientID' since it's not related with risk prediction
df = df.drop(columns = ['clientID'])

# %%
# Change 'dateID' object to float
df['dateID'] = pd.to_datetime(df['dateID'], format = '%Y-%m-%d')
df['Day'] = df['dateID'].dt.day
df['Month'] = df['dateID'].dt.month
df['Year'] = df['dateID'].dt.year
df.drop(columns = ['dateID'], inplace = True)

# %%
# Get dummy values for categorical predictor 'education'
df = pd.get_dummies(df, prefix = ['education'], columns = ['education'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50400 entries, 1 to 71999
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   risk                      50400 non-null  float64
#  1   avgMonthlyIncome          50400 non-null  float64
#  2   expSavings                50400 non-null  float64
#  3   expTransport              50400 non-null  float64
#  4   expGroceries              50400 non-null  float64
#  5   expLeisure                50400 non-null  float64
#  6   expShopping               50400 non-null  float64
#  7   expUtilities              50400 non-null  float64
#  8   expOther                  50400 non-null  float64
#  9   cardLevel                 50400 non-null  int64
#  10  amountDeposit             50400 non-null  float64
#  11  amountLoan                50400 non-null  float64
#  12  avgTransaction            50400 non-null  float64
#  13  avgNumTransactions        50400 non-null  float64
#  14  largestSingleTransaction  50400 non-null  float64
#  15  Day                       50400 non-null  int64
#  16  Month                     50400 non-null  int64
#  17  Year                      50400 non-null  int64
#  18  education_BSc             50400 non-null  uint8
#  19  education_MSc             50400 non-null  uint8
#  20  education_PhD             50400 non-null  uint8
#  21  education_college         50400 non-null  uint8
# dtypes: float64(14), int64(4), uint8(4)
# memory usage: 7.5 MB

# %%
# Plot the relationship between the response variable 'risk' and predictors to see if they may be linearly related
plt.scatter(df['avgMonthlyIncome'], y = df['risk'])

# %%
plt.scatter(df['expSavings'], y = df['risk'])

# %%
plt.scatter(df['expTransport'], y = df['risk'])

# %% [markdown]
# It's unlikely that linear regression will be a good model from these graphs. However, let's first try linear regression model to see how it fits the data.

# %%
# Split train and test sets
from sklearn.model_selection import train_test_split
x = df.drop(['risk'], axis = 1)
y = df['risk']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 10)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((40320, 22), (10080, 22), (40320,), (10080,))

# %%
train = pd.concat([x_train, y_train], axis = 1)

# %%
test = pd.concat([x_test, y_test], axis = 1)

# %% [markdown]
# # LINEAR REGRESSION MODEL

# %%
# Linear regression model
import statsmodels.formula.api as smf
LR_model = smf.ols(formula = 'risk ~' + '+'.join(train.columns.difference(['risk'])), data = train).fit()

# %%
from sklearn.metrics import r2_score

preds_LR = LR_model.predict(x_train)
print(f'R2 of linreg-model: {r2_score(y_train, preds_LR)}')
preds_LR = LR_model.predict(x_test)
print(f'R2 of linreg-model OOS: {r2_score(y_test, preds_LR)}')
# Out:
# R2 of linreg-model: 0.7321745396554017
# R2 of linreg-model OOS: 0.7259103900957402

# %%
LR_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   risk   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     5798.
# Date:                Fri, 03 Mar 2023   Prob (F-statistic):               0.00
# Time:                        18:56:13   Log-Likelihood:                 41596.
# No. Observations:               40320   AIC:                        -8.315e+04
# Df Residuals:                   40300   BIC:                        -8.298e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.5265      0.227      2.317      0.020       0.081       0.972
# Day                          0.5265      0.227      2.317      0.020       0.081       0.972
# Month                     1.303e-05      0.000      0.104      0.917      -0.000       0.000
# Year                        -0.0003      0.000     -1.017      0.309      -0.001       0.000
# amountDeposit            -6.312e-09   4.65e-09     -1.357      0.175   -1.54e-08    2.81e-09
# amountLoan               -2.287e-07   6.54e-09    -34.965      0.000   -2.41e-07   -2.16e-07
# avgMonthlyIncome         -1.317e-08   2.08e-09     -6.345      0.000   -1.72e-08    -9.1e-09
# avgNumTransactions        1.031e-05   1.44e-06      7.141      0.000    7.48e-06    1.31e-05
# avgTransaction            1.143e-07   2.73e-08      4.186      0.000    6.08e-08    1.68e-07
# cardLevel                    0.0209      0.000     46.321      0.000       0.020       0.022
# education_BSc                0.1553      0.057      2.734      0.006       0.044       0.267
# education_MSc                0.2222      0.057      3.912      0.000       0.111       0.334
# education_PhD                0.2373      0.057      4.177      0.000       0.126       0.349
# education_college           -0.0883      0.057     -1.554      0.120      -0.200       0.023
# expGroceries                -0.0313      0.058     -0.535      0.592      -0.146       0.083
# expLeisure                  -0.0296      0.058     -0.510      0.610      -0.143       0.084
# expOther                    -0.0213      0.058     -0.365      0.715      -0.136       0.093
# expSavings                  -0.0374      0.059     -0.638      0.524      -0.152       0.077
# expShopping                 -0.0186      0.058     -0.318      0.750      -0.133       0.096
# expTransport                -0.0358      0.058     -0.616      0.538      -0.150       0.078
# expUtilities                -0.0200      0.058     -0.342      0.732      -0.134       0.094
# largestSingleTransaction -3.146e-08   6.16e-09     -5.107      0.000   -4.35e-08   -1.94e-08
# ==============================================================================
# Omnibus:                     8443.516   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75517.760
# Skew:                          -0.756   Prob(JB):                         0.00
# Kurtosis:                       9.532   Cond. No.                     1.99e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.58e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# We can observe from the p-value that variables 'amountLoan', 'avgMonthlyIncome', 'avgNumTransactions', 'avgTransaction', 'cardLevel', 'education_BSc', 'education_MSc', 'education_PhD', 'largestSingleTransaction' can be concluded as significant variables.

# %% [markdown]
# # REGRESSION TREE MODEL

# %%
# Regression tree model
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

# Range for the complexity parameter value
grid_values = {'ccp_alpha': np.linspace(0, 0.001, 51)}

# The decision tree regressor
dtr = DecisionTreeRegressor(min_samples_leaf = 5, min_samples_split = 10, random_state = 10)

# To find the optimal complexity parameter value using 5-fold cross validation
dtr_cv = GridSearchCV(dtr, param_grid = grid_values, scoring = 'r2', cv = 5 , verbose = 0)
dtr_cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=DecisionTreeRegressor(min_samples_leaf=5,
#                                              min_samples_split=10,
#                                              random_state=10),
#              param_grid={'ccp_alpha': array([0.0e+00, 2.0e-05, 4.0e-05, 6.0e-05, 8.0e-05, 1.0e-04, 1.2e-04,
#        1.4e-04, 1.6e-04, 1.8e-04, 2.0e-04, 2.2e-04, 2.4e-04, 2.6e-04,
#        2.8e-04, 3.0e-04, 3.2e-04, 3.4e-04, 3.6e-04, 3.8e-04, 4.0e-04,
#        4.2e-04, 4.4e-04, 4.6e-04, 4.8e-04, 5.0e-04, 5.2e-04, 5.4e-04,
#        5.6e-04, 5.8e-04, 6.0e-04, 6.2e-04, 6.4e-04, 6.6e-04, 6.8e-04,
#        7.0e-04, 7.2e-04, 7.4e-04, 7.6e-04, 7.8e-04, 8.0e-04, 8.2e-04,
#        8.4e-04, 8.6e-04, 8.8e-04, 9.0e-04, 9.2e-04, 9.4e-04, 9.6e-04,
#        9.8e-04, 1.0e-03])},
#              scoring='r2')

# %%
# Print the optimal complexity parameter value for our model
print('Best ccp_alpha', dtr_cv.best_params_)
# Out:
# Best ccp_alpha {'ccp_alpha': 2e-05}

# %%
# Regression tree model with the optimal ccp alpha value
dtr_final = DecisionTreeRegressor(min_samples_leaf = 5, 
                                  min_samples_split = 20, 
                                  ccp_alpha = 2e-05,
                                  random_state = 10)
dtr_final.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=2e-05, min_samples_leaf=5, min_samples_split=20,
#                       random_state=10)

# %%
# Random forest model
from sklearn.ensemble import RandomForestRegressor

# Range for the max_features
grid_values = {'max_features': np.linspace(1,18,9, dtype = 'int32')} 

# Random forest model
rf = RandomForestRegressor(min_samples_leaf = 5, n_estimators = 500, random_state = 10) 

# Choosing the max features by a 5-fold cross validation
rf_cv = GridSearchCV(rf, param_grid = grid_values, scoring = 'r2', cv = 5)
rf_cv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestRegressor(min_samples_leaf=5,
#                                              n_estimators=500,
#                                              random_state=10),
#              param_grid={'max_features': array([ 1,  3,  5,  7,  9, 11, 13, 15, 18], dtype=int32)},
#              scoring='r2')

# %%
print(rf_cv.best_params_)
# Out:
# {'max_features': 1}

# %%
# Random forest model with the optimal max_features value
rf_final = RandomForestRegressor(min_samples_leaf = 5, 
                                 n_estimators = 500, 
                                 max_features = 15,
                                 random_state = 10) 
rf_final.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features=15, min_samples_leaf=5, n_estimators=500,
#                       random_state=10)

# %%
# Define a function to compute the out-of-sample R-squared of a model using the test set
def OSR2(model, df_train, df_test, dependent_var):   
    
    y_test = df_test[dependent_var]
    y_pred = model.predict(df_test)
    SSE = np.sum((y_test - y_pred)**2)
    SST = np.sum((y_test - np.mean(df_train[dependent_var]))**2)    
    
    return 1 - SSE/SST

# %% [markdown]
# # EVALUATION

# %%
pd.DataFrame({'R2 Score':[OSR2(LR_model, train, test, 'risk'), 
                          round(r2_score(y_test, dtr_final.predict(x_test)), 5),
                          round(r2_score(y_test, rf_final.predict(x_test)), 5)
                          ],
            },
             index=['Linear Regression', "Regression Tree", "Random Forest"])
# Out:
#                    R2 Score
# Linear Regression  0.725935
# Regression Tree    0.902170
# Random Forest      0.930490

# %% [markdown]
# Based on $OSR^2$ values, random forest model performs the best.

# %% [markdown]
# # NON CONTINUOUS VARIABLE -- CLASSIFICATION
# We tried to define a user with risky investment behavior, when the risk is greater than 0.5.

# %%
from sklearn.model_selection import train_test_split

df["risky_behaviour"] = [1 if x > 0.5 else 0 for x in df["risk"]]

x = df.drop(['risk', 'risky_behaviour'], axis = 1)
y = df['risky_behaviour']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 10)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((40320, 21), (10080, 21), (40320,), (10080,))

# %% [markdown]
# Using a **Linear Regression Model** to make predictions

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

linreg = LinearRegression().fit(x_train, y_train)

# %%
preds = linreg.predict(x_train)
print(f'R2 of linreg-model: {r2_score(y_train, preds)}')
preds = linreg.predict(x_test)
print(f'R2 of linreg-model OOS: {r2_score(y_test, preds)}')
# Out:
# R2 of linreg-model: 0.6989116891797507
# R2 of linreg-model OOS: 0.6930886534407916

# %% [markdown]
# Using a **Random Forests** to make predictions

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
x_train.shape
# Out:
# (40320, 21)

# %%
parameters = {'max_samples': range(1,x_train.shape[1]), 
              'ccp_alpha':[10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 10**0, 10**1]
             }

rf_gridsearch = GridSearchCV(estimator=RandomForestRegressor(), param_grid=parameters, error_score='raise').fit(x_train, y_train)
bp = rf_gridsearch.best_params_
bp
# Out:
# {'ccp_alpha': 0.01, 'max_samples': 20}

# %%
rf = RandomForestRegressor(bootstrap=True, ccp_alpha=bp['ccp_alpha'], max_samples=bp['max_samples']).fit(x_train, y_train)

# %%
preds = rf.predict(x_train)
print(f'R2 of random forest model: {r2_score(y_train, preds)}')
preds = rf.predict(x_test)
print(f'R2 of random forest model OOS: {r2_score(y_test, preds)}')
# Out:
# R2 of random forest model: 0.7212725891480006
# R2 of random forest model OOS: 0.7165737217252773

# %% [markdown]
# Using a **Ridge Regression** to make predictions

# %%
from sklearn.linear_model import Ridge

# %%
parameters = {'alpha': [x/100 for x in range(0,101)]}

rr_gridsearch = GridSearchCV(estimator=Ridge(), param_grid=parameters).fit(x_train, y_train)
bp = rr_gridsearch.best_params_
bp
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.15865e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.16803e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.19433e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.19019e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.17977e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.43173e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.4336e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.43886e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.43804e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.43595e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.14759e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15039e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15829e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15705e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15392e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.86345e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.86718e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.87772e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.87606e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.87188e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.5793e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.58397e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.59715e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.59507e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.58984e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.29516e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.30076e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.31657e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.31409e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.3078e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.01101e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.01754e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.036e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.03309e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.02576e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.72687e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.73432e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.75542e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.7521e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.74371e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.44272e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.45109e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.47484e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.47111e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.46166e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.15857e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.16787e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.19426e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.19011e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.17961e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.87442e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.88464e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.91368e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.90912e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.89756e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.59027e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.60141e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.6331e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.62812e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.6155e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.30611e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.31818e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.35252e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.34712e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.33344e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.0022e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.00349e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.00719e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.00661e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.00514e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07378e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07517e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07913e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07851e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.07693e-16): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# {'alpha': 1.0}

# %%
rr = Ridge(alpha=bp['alpha']).fit(x_train, y_train)

# %%
preds = rr.predict(x_train)
print(f'R2 of ridge regression model: {r2_score(y_train, preds)}')
preds = rr.predict(x_test)
print(f'R2 of ridge regression OOS: {r2_score(y_test, preds)}')
# Out:
# R2 of ridge regression model: 0.6989034430464365
# R2 of ridge regression OOS: 0.6930919733947384

# %% [markdown]
# Using a **Logistic Regression** to make predictions

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Logistic Regression model
log_reg = LogisticRegression(random_state=55, max_iter=2000) 
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=55)

# %% [markdown]
# **Result** - Logistic Regression Model

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
y_prob = log_reg.predict_proba(x_test)
y_pred_log = pd.Series([1 if x > 0.5 else 0 for x in y_prob[:,1]], index=y_test.index)
                       
cm_log = confusion_matrix(y_test, y_pred_log)
print ("Confusion Matrix: \n", cm_log)
# Out:
# Confusion Matrix:
#  [[  61 2488]
#  [  17 7514]]

# %%
acc_log = accuracy_score(y_test, y_pred_log)
TPR_log = cm_log[1][1]/(cm_log[1][0]+cm_log[1][1])
FPR_log = cm_log[0][1]/(cm_log[0][0]+cm_log[0][1])

print ("Accuracy:", acc_log)
print ("TPR:", TPR_log)
print ("FPR:", FPR_log)
# Out:
# Accuracy: 0.7514880952380952
# TPR: 0.9977426636568849
# FPR: 0.9760690466849745

# %%
import seaborn as sns

conf_matrix = pd.DataFrame(data=cm_log, columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize = (8,5))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Using **CART** to make predictions

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

grid_values = {'ccp_alpha': np.linspace(0, 0.1, 1)}

dtc = DecisionTreeClassifier(random_state=88)
dtc_cv = GridSearchCV(dtc, param_grid=grid_values, cv=2).fit(x_train, y_train)

# %% [markdown]
# **Result** - CART

# %%
from sklearn.tree import plot_tree

print('Node count =', dtc_cv.best_estimator_.tree_.node_count)

plt.figure(figsize=(6,6))
plot_tree(dtc_cv.best_estimator_, 
          feature_names=x_train.columns, 
          class_names=['0','1'], 
          filled=True,
          impurity=False,
          fontsize=12) 

plt.show()
# Out:
# Node count = 1483

# %%
y_pred_dtc = dtc_cv.predict(x_test)
cm_dtc = confusion_matrix(y_test, y_pred_dtc)
print ("Confusion Matrix: \n", cm_dtc)
# Out:
# Confusion Matrix:
#  [[2410  139]
#  [ 142 7389]]

# %%
acc_dtc = accuracy_score(y_test, y_pred_dtc)
TPR_dtc = cm_dtc[1][1]/(cm_dtc[1][0]+cm_dtc[1][1])
FPR_dtc = cm_dtc[0][1]/(cm_dtc[0][0]+cm_dtc[0][1])

print ("Accuracy:", acc_dtc)
print ("TPR:", TPR_dtc)
print ("FPR:", FPR_dtc)
# Out:
# Accuracy: 0.9721230158730159
# TPR: 0.9811446023104501
# FPR: 0.05453118870145155

# %% [markdown]
# Using **LDA** to make predictions

# %%
# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()
lda.fit(x_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
y_prob = lda.predict_proba(x_test)
y_pred_lda = pd.Series([1 if x > 0.5 else 0 for x in y_prob[:,1]], index=y_test.index)

cm_lda = confusion_matrix(y_test, y_pred_lda)
print ("Confusion Matrix: \n", cm_lda)
# Out:
# Confusion Matrix:
#  [[2366  183]
#  [ 533 6998]]

# %%
acc_lda = accuracy_score(y_test, y_pred_lda)
TPR_lda = cm_lda[1][1]/(cm_lda[1][0]+cm_lda[1][1])
FPR_lda = cm_lda[0][1]/(cm_lda[0][0]+cm_lda[0][1])

print ("Accuracy:", acc_lda)
print ("TPR:", TPR_lda)
print ("FPR:", FPR_lda)
# Out:
# Accuracy: 0.928968253968254
# TPR: 0.9292258664188023
# FPR: 0.0717928599450765

# %% [markdown]
# # EVALUATION

# %%
# Calculate AUC
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y_test, y_pred_log)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.title('ROC Curve Logistic regression', fontsize=18)
plt.xlabel('FPR', fontsize=16)
plt.ylabel('TPR', fontsize=16)
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr, tpr, lw=3, label='Logistic Regression (area = {:0.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
plt.legend(loc='lower right', fontsize=14)
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_dtc)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.title('ROC Curve CART', fontsize=18)
plt.xlabel('FPR', fontsize=16)
plt.ylabel('TPR', fontsize=16)
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr, tpr, lw=3, label='Logistic Regression (area = {:0.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
plt.legend(loc='lower right', fontsize=14)
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred_lda)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.title('ROC Curve LDA', fontsize=18)
plt.xlabel('FPR', fontsize=16)
plt.ylabel('TPR', fontsize=16)
plt.xlim([-0.01, 1.00])
plt.ylim([-0.01, 1.01])
plt.plot(fpr, tpr, lw=3, label='Logistic Regression (area = {:0.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=3, linestyle='--')
plt.legend(loc='lower right', fontsize=14)
plt.show()

# %%
pd.DataFrame({'Logistic Regression':[acc_log,TPR_log,FPR_log],
             'CART':[acc_dtc,TPR_dtc,FPR_dtc],
             'LDA':[acc_lda,TPR_lda,FPR_lda]},
             index=['Accuracy','TPR','FPR'])
# Out:
#           Logistic Regression      CART       LDA
# Accuracy             0.751488  0.972123  0.928968
# TPR                  0.997743  0.981145  0.929226
# FPR                  0.976069  0.054531  0.071793
